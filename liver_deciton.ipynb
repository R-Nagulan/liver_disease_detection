# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\liver_disease_detection\Book2.csv")

# %%
display(df)
# Out:
#      Age Gender  Alanine Aminotransferase(U/L)_ALT  \
# 0     64   Male                               58.0
# 1     35   Male                               47.0
# 2     72   Male                               39.0
# 3     73   Male                               35.0
# 4     64   Male                               44.0
# ..   ...    ...                                ...
# 361   25   Male                               18.7
# 362   30   Male                               69.0
# 363   48   Male                               81.0
# 364   54   Male                              113.0
# 365   68   Male                               63.0
#
#      Aspartate Aminotransferase(U/L)_AST  Alkaline phosphatase(U/L)_ALP  \
# 0                                   75.0                            NaN
# 1                                  263.0                            NaN
# 2                                   60.0                            NaN
# ...
